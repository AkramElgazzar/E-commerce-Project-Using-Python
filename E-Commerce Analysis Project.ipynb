# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("Ecommerce Data")
df.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...

# %%
# data type of each column

df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
df.tail()
# Out:
#                                                 Address    Lot AM or PM  \
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                        Company       Credit Card CC Exp Date  \
# 9995             Randall-Sloan   342945015358701       03/22
# 9996  Hale, Collins and Wilson   210033169205009       07/25
# ...

# %% [markdown]
# CHECKING NULL VALUES

# %%
# to count null values 

df.isnull()
# Out:
#       Address    Lot  AM or PM  Browser Info  Company  Credit Card  \
# 0       False  False     False         False    False        False
# 1       False  False     False         False    False        False
# 2       False  False     False         False    False        False
# 3       False  False     False         False    False        False
# 4       False  False     False         False    False        False
# ...       ...    ...       ...           ...      ...          ...
# 9995    False  False     False         False    False        False
# 9996    False  False     False         False    False        False
# 9997    False  False     False         False    False        False
# 9998    False  False     False         False    False        False
# 9999    False  False     False         False    False        False
#
#       CC Exp Date  CC Security Code  CC Provider  Email    Job  IP Address  \
# 0           False             False        False  False  False       False
# ...

# %% [markdown]
# CHECKING NO. OF ROWS AND COLUMNS IN THE DATASET

# %%
df.shape
# Out:
# (10000, 14)

# %%
# only see columns name in dataset

df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
# count no. of columns in datset

len(df.columns)
# Out:
# 14

# %%
# to see only purchase price column

df['Purchase Price']
# Out:
# 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: Purchase Price, Length: 10000, dtype: float64

# %%
# highest purchase price

df['Purchase Price'].max()
# Out:
# 99.99

# %%
# lowest purchase price

df['Purchase Price'].min()
# Out:
# 0.0

# %%
# checking standard deviation

df['Purchase Price'].std()
# Out:
# 29.015836309789048

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
# to see the information of people whose language is french


df[df['Language']=="fr"]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 53                PSC 9431, Box 7059\nAPO AA 29285-1363  14 qD       AM
# 76    49206 Campbell Port\nNorth Cliffordshire, HI 3...  71 iu       PM
# 82    493 Smith Valleys Suite 004\nNew Madelineville...  35 ls       PM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9951                518 Brown Dam\nGarciaside, IN 33057  71 wq       AM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9980           6061 Dave Lights\nPhillipsview, UT 40500  25 Mv       AM
#
#                                            Browser Info  \
# ...

# %%
# to count how many people have french language


df[df["Language"] == "fr"].count()
# Out:
# Address             1097
# Lot                 1097
# AM or PM            1097
# Browser Info        1097
# Company             1097
# Credit Card         1097
# CC Exp Date         1097
# CC Security Code    1097
# CC Provider         1097
# Email               1097
# Job                 1097
# IP Address          1097
# Language            1097
# Purchase Price      1097
# dtype: int64

# %%
# to get engineer's informations
# str.contains will print wherever there is "engineer" in job
# returns a boolean array


df["Job"].str.contains("engineer" , case = False)
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: Job, Length: 10000, dtype: bool

# %%
# to get all the informations about engineers

df[df["Job"].str.contains("engineer" , case = False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
# to find out total engineers 

len(df[df["Job"].str.contains("engineer" , case = False)])
# Out:
# 984

# %%
# ALTERNATIVE WAY
# to find out total engineers 

df[df["Job"].str.contains("engineer" , case = False)].count()
# Out:
# Address             984
# Lot                 984
# AM or PM            984
# Browser Info        984
# Company             984
# Credit Card         984
# CC Exp Date         984
# CC Security Code    984
# CC Provider         984
# Email               984
# Job                 984
# IP Address          984
# Language            984
# Purchase Price      984
# dtype: int64

# %%
# showing full info of the person having this ip address

df[df['IP Address'] == "213.203.143.215"]
# Out:
#                                             Address    Lot AM or PM  \
# 50  41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
#
#                                          Browser Info  \
# 50  Mozilla/5.0 (Windows 98; Win 9x 4.90; sl-SI; r...
#
#                         Company       Credit Card CC Exp Date  \
# 50  Wright, Williams and Mendez  4008586485908075       05/19
#
#     CC Security Code   CC Provider                      Email  \
# 50               945  JCB 16 digit  susanvalentine@obrien.org
#
#                     Job       IP Address Language  Purchase Price
# 50  Mechanical engineer  213.203.143.215       de           36.85

# %%
# showing email of the person with this ip address 

df["Email"][df['IP Address'] == "213.203.143.215"]
# Out:
# 50    susanvalentine@obrien.org
# Name: Email, dtype: object

# %%
# people who use mastercard credit card

df[df["CC Provider"] == "Mastercard"].head()
# Out:
#                                               Address    Lot AM or PM  \
# 1   9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18  461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                   USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35  93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 41  779 Sydney Keys Apt. 119\nAnthonyside, NH 2179...  21 lh       PM
#
#                                          Browser Info  \
# 1   Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 18  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
# 31  Opera/8.84.(X11; Linux i686; sl-SI) Presto/2.9...
# 35  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 41  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...
#
#                             Company       Credit Card CC Exp Date  \
# 1   Fletcher, Richards and Whitaker  3337758169645356       11/18
# 18           Beard, Abbott and Pena  6011350184276270       12/22
# ...

# %%
# no. of people having master card credit card

df[df["CC Provider"] == "Mastercard"].count()
# Out:
# Address             816
# Lot                 816
# AM or PM            816
# Browser Info        816
# Company             816
# Credit Card         816
# CC Exp Date         816
# CC Security Code    816
# CC Provider         816
# Email               816
# Job                 816
# IP Address          816
# Language            816
# Purchase Price      816
# dtype: int64

# %%
# people having master card and made purchase of more than 80 


df[(df["CC Provider"] == "Mastercard") & (df["Purchase Price"] > 80)]
# Out:
#                                                 Address    Lot AM or PM  \
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 120     70617 Robert Bypass\nNorth Anita, AR 86445-2370  78 RT       PM
# 159               PSC 1717, Box 9046\nAPO AP 75015-9066  37 SP       PM
# 166         8991 Sutton Unions\nDiazview, TN 65790-2439  24 uq       PM
# ...                                                 ...    ...      ...
# 9539  7656 Brian Points Apt. 746\nPort William, IN 2...  39 KL       PM
# 9601              PSC 4140, Box 4384\nAPO AP 02202-0817  51 YB       AM
# 9667                   PSC 3356, Box 6599\nAPO AP 80069  20 oN       AM
# 9825       21339 Cardenas Avenue\nMeyersmouth, IA 67085  13 uy       PM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
#
#                                            Browser Info  \
# ...

# %%
# printing just a single column i.e,email of the person having this credit card number


df['Email'][df['Credit Card'] == 6011717863041987]
# Out:
# 9601    gloriathornton@jones-ferguson.com
# Name: Email, dtype: object

# %%
# count of unique values in "AM OR PM" column

df['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
# finding no. of customers segregated according to language they speak


df['Language'].value_counts()
# Out:
# ru    1155
# de    1155
# el    1137
# pt    1118
# en    1098
# fr    1097
# es    1095
# it    1086
# zh    1059
# Name: Language, dtype: int64

# %%
# calculating total customers who speak french

df[df['Language'] == "fr"].count()
# Out:
# Address             1097
# Lot                 1097
# AM or PM            1097
# Browser Info        1097
# Company             1097
# Credit Card         1097
# CC Exp Date         1097
# CC Security Code    1097
# CC Provider         1097
# Email               1097
# Job                 1097
# IP Address          1097
# Language            1097
# Purchase Price      1097
# dtype: int64

# %%
# calculating number of people who made purchases in feb,2020


df[df["CC Exp Date"].str.contains("02/20")].count()
# Out:
# Address             75
# Lot                 75
# AM or PM            75
# Browser Info        75
# Company             75
# Credit Card         75
# CC Exp Date         75
# CC Security Code    75
# CC Provider         75
# Email               75
# Job                 75
# IP Address          75
# Language            75
# Purchase Price      75
# dtype: int64

# %%
# top 5 e-mail providers

list1 = []
for each in df["Email"] :
    list1.append(each.split('@')[1])
    
    
df["email_provider"] = list1
df.head(1)



df["email_provider"].value_counts()


df["email_provider"].value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: email_provider, dtype: int64

# %%
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# email_provider       object
# dtype: object

# %%
# Check Null Values In The Dataset

df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# email_provider      0
# dtype: int64

# %%
# checking unique values in the dataset

df.notnull().sum()
# Out:
# Address             10000
# Lot                 10000
# AM or PM            10000
# Browser Info        10000
# Company             10000
# Credit Card         10000
# CC Exp Date         10000
# CC Security Code    10000
# CC Provider         10000
# Email               10000
# Job                 10000
# IP Address          10000
# Language            10000
# Purchase Price      10000
# email_provider      10000
# dtype: int64

# %%
df['Purchase Price'].max()
# Out:
# 99.99

# %%
df['Purchase Price'].min()
# Out:
# 0.0

# %%
# Finding standard deviation of the purchase price

df['Purchase Price'].std()
# Out:
# 29.015836309789048

# %%
# How many people have German 'de' as their Language ?
 
len(df[df['Language'] == 'de'])
# Out:
# 1155

# %%
# Job Title Contains Artist

df[df['Job'].str.contains("artist", case = False )].head(7)
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 358        7899 Powell Forges\nOconnorborough, VT 37086  99 gQ       AM
# 380    3332 John Track\nLake Codychester, GU 79028-7324  58 cI       PM
# 546         815 Timothy Parks\nGreenfort, SC 79838-1050  27 zS       AM
# 636   19594 Irwin Forge Apt. 967\nBrianville, MI 143...  58 Gj       PM
# 1126  39688 Mitchell Viaduct\nWest Johnnymouth, KY 1...  83 dA       AM
# 1225    916 Amanda Heights\nNew Johnland, CA 52112-8572  09 vg       PM
#
#                                            Browser Info  \
# 4     Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
# 358   Mozilla/5.0 (X11; Linux i686) AppleWebKit/5341...
# 380   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 546   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_6 ...
# 636   Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
# People having maestro as their credit card provider 

df[df['CC Provider'] == 'Maestro'].tail(-5)
# Out:
#                                                 Address    Lot AM or PM  \
# 100        9980 Ramirez Grove\nSmithview, AZ 13342-4996  34 bB       AM
# 114               Unit 0282 Box 9769\nDPO AP 05162-2277  72 zO       AM
# 117            853 Ayers Forges\nEast Tiffany, MP 15967  95 Os       PM
# 118           036 Johnson Station\nPort Patty, OR 56686  81 DC       AM
# 123   81601 Jordan Creek Apt. 759\nPort Scott, CT 87078  01 Gx       PM
# ...                                                 ...    ...      ...
# 9958                   PSC 8781, Box 4214\nAPO AP 94478  72 Ez       AM
# 9966        433 Jeffrey Plain\nEast Troy, LA 47554-8117  18 gm       AM
# 9984       7560 Boyle Keys\nAntoniomouth, DC 00522-0367  72 Qb       AM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
#
#                                            Browser Info  \
# ...

# %%
# engineers having maestro credit card


df[(df['CC Provider'] == 'Maestro') & (df['Job'].str.contains("engineer" , case = False))]
# Out:
#                                                 Address    Lot AM or PM  \
# 192   427 Young Lodge Suite 914\nWest Nicholastown, ...  49 KL       PM
# 246       666 Davis Junction\nEast Destinyton, IL 88122  50 WE       PM
# 395   61341 Brittany Plains Suite 994\nEast Johnview...  22 IN       PM
# 413                     USNV Johnson\nFPO AP 78193-2799  52 qj       AM
# 492                    PSC 6288, Box 9865\nAPO AE 40968  48 Tu       PM
# ...                                                 ...    ...      ...
# 9351          65595 William Dale\nSouth Craig, MI 55954  22 oQ       AM
# 9399  38131 Sandra Islands\nPort Robertview, HI 0735...  02 ms       PM
# 9673        6368 Kayla Avenue\nNew Sharonland, CT 36967  54 Si       PM
# 9852  0528 Christina Greens Suite 743\nAllisonberg, ...  81 qO       AM
# 9898          0715 Jennifer Land\nRichardstad, VA 58683  99 nw       PM
#
#                                            Browser Info  \
# ...

# %%
# how many engineers having maestro credit card


df[(df['CC Provider'] == 'Maestro') & (df['Job'].str.contains("engineer" , case = False))].count()
# Out:
# Address             86
# Lot                 86
# AM or PM            86
# Browser Info        86
# Company             86
# Credit Card         86
# CC Exp Date         86
# CC Security Code    86
# CC Provider         86
# Email               86
# Job                 86
# IP Address          86
# Language            86
# Purchase Price      86
# email_provider      86
# dtype: int64

# %%
# Find Email of The Person With The Following Credit Card Number: 4664825258997302


df[df['Credit Card'] == 4664825258997302]['Email']
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %%
# How Many Spanish People Purchase During The AM and How Many People Purchase During PM ?


len(df[(df['AM or PM']=='AM') & (df['Language'] == 'es')])
# Out:
# 540

# %%
# How Many People have A Credit Card That Expires In 2025?


df[df['CC Exp Date'].str.contains("/25")]
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 13    118 Melton Via Suite 681\nAlexanderbury, FL 32104  36 bu       PM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# ...                                                 ...    ...      ...
# 9955      66539 Potts Forge\nCartershire, AK 58271-5180  37 KB       AM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
df['Job'].value_counts()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Special effects artist            7
# Editor, film/video                6
# Actuary                           6
# Investment analyst                5
# Information systems manager       5
# Name: Job, Length: 623, dtype: int64

# %%
df['CC Provider'].value_counts()
# Out:
# JCB 16 digit                   1716
# VISA 16 digit                  1715
# JCB 15 digit                    868
# American Express                849
# Maestro                         846
# Voyager                         829
# Discover                        817
# Mastercard                      816
# VISA 13 digit                   777
# Diners Club / Carte Blanche     767
# Name: CC Provider, dtype: int64
